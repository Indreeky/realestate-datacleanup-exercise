# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

df = pd.read_csv('assets/real_estate.csv', sep=';')
df
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
casa_mas_cara = df.loc[df['price'].idxmax()]
direccion = casa_mas_cara['address']
precio = casa_mas_cara['price']
print(f"La casa con la dirección {direccion} es la más cara y su precio es de {precio} EUR")
# Out:
# La casa con la dirección El Escorial es la más cara y su precio es de 8500000 EUR

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
casa_mas_barata = df.loc[df['price'].idxmin()]
direccion = casa_mas_barata['address']
precio = casa_mas_barata['price']
print(f"La casa con la dirección {direccion} es la más barata y su precio es de {precio} EUR")
# Out:
# La casa con la dirección Parla es la más barata y su precio es de 0 EUR

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
casa_mas_grande = df.loc[df['surface'].idxmax()]
casa_mas_pequeña = df.loc[df['surface'].idxmin()]
direccion_grande = casa_mas_grande['address']
area_grande = casa_mas_grande['surface']
direccion_pequena = casa_mas_pequeña['address']
area_pequena = casa_mas_pequeña['surface']
print(f"La casa más grande está ubicada en {direccion_grande} y su superficie es de {area_grande} metros")
print(f"La casa más pequeña está ubicada en {direccion_pequena} y su superficie es de {area_pequena} metros")
# Out:
# La casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros
# La casa más pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
poblaciones = df['level5'].unique()
poblaciones_comas = ', '.join(poblaciones)
print(f"Total de poblaciones: {len(poblaciones)}")
print(poblaciones_comas)
# Out:
# Total de poblaciones: 168
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
tiene_na = df.isnull().values.any()
if tiene_na:
    filas_columnas_na = df.isnull().stack()[df.isnull().stack()].index.tolist()
    print("True")
    print("filas y columnas con NAs:")
    for fila_columna in filas_columnas_na:
        print(f"fila: {fila_columna[0]}, columna: {fila_columna[1]}")
else:
    print("False")
# Out:
# True
# filas y columnas con NAs:
# fila: 0, columna: level6
# fila: 0, columna: level8
# fila: 0, columna: zipCode
# fila: 0, columna: customZone
# fila: 1, columna: surface
# fila: 1, columna: level6
# fila: 1, columna: level8
# fila: 1, columna: zipCode
# fila: 1, columna: customZone
# fila: 2, columna: level6
# fila: 2, columna: level8
# fila: 2, columna: zipCode
# fila: 2, columna: customZone
# fila: 3, columna: level6
# fila: 3, columna: level8
# fila: 3, columna: zipCode
# fila: 3, columna: customZone
# fila: 4, columna: level6
# fila: 4, columna: level8
# fila: 4, columna: zipCode
# fila: 4, columna: customZone
# fila: 5, columna: level6
# fila: 5, columna: level8
# fila: 5, columna: zipCode
# fila: 5, columna: customZone
# fila: 6, columna: level6
# fila: 6, columna: level8
# fila: 6, columna: zipCode
# fila: 6, columna: customZone
# fila: 7, columna: level6
# fila: 7, columna: level8
# fila: 7, columna: zipCode
# fila: 7, columna: customZone
# fila: 8, columna: level6
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
dimension_original = df.shape
print(f"Dimensiones del DataFrame original: {dimension_original}")
df_sin_nas = df.dropna()
dimension_sin_nas = df_sin_nas.shape
print(f"Dimensiones del DataFrame después de eliminar los NAs: {dimension_sin_nas}")
# Out:
# Dimensiones del DataFrame original: (15335, 37)
# Dimensiones del DataFrame después de eliminar los NAs: (0, 37)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
arroyomolinos = df[df['level5'] == 'Arroyomolinos (Madrid)']
media_precio_arroyomolinos = arroyomolinos['price'].mean()
print(f"La media de precios en la población Arroyomolinos es: {media_precio_arroyomolinos:.2f} EUR")
# Out:
# La media de precios en la población Arroyomolinos es: 294541.60 EUR

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
import matplotlib.pyplot as plt

# %%
arroyomolinos = df[df['level5'] == 'Arroyomolinos (Madrid)']
plt.hist(arroyomolinos['price'], color='cyan', bins=10, edgecolor='black')
plt.title('Histograma de Precios en Arroyomolinos (Madrid)')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# La mayoría de las casas se encuentran en un rango de precios entre 200,000 y 400,000 euros, con un pico notable alrededor de los 300,000 euros, lo que indica que es el precio más común. Hay pocas viviendas por debajo de los 200,000 euros y algunas dispersas por encima de los 400,000 euros.

# %% [markdown]
# #### Exercise 09. Are the averages of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
valdemorillo = df[df['level5'] == 'Valdemorillo']
galapagar = df[df['level5'] == 'Galapagar']
media_precio_valdemorillo = valdemorillo['price'].mean()
media_precio_galapagar = galapagar['price'].mean()
print(f"La media de precios en Valdemorillo es: {media_precio_valdemorillo:.2f} EUR")
print(f"La media de precios en Galapagar es: {media_precio_galapagar:.2f} EUR")
print("Los precios promedios en Valdemorillo y Galapagar son similares.")
# Out:
# La media de precios en Valdemorillo es: 363860.29 EUR
# La media de precios en Galapagar es: 360063.20 EUR
# Los precios promedios en Valdemorillo y Galapagar son similares.

# %% [markdown]
# #### Exercise 10. Are the averages of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
df['pps'] = df['price'] / df['surface']
valdemorillo = df[df['level5'] == 'Valdemorillo']
galapagar = df[df['level5'] == 'Galapagar']
media_pps_valdemorillo = valdemorillo['pps'].mean()
media_pps_galapagar = galapagar['pps'].mean()
print(f"La media de precio por metro cuadrado en Valdemorillo es: {media_pps_valdemorillo:.2f} EUR/m²")
print(f"La media de precio por metro cuadrado en Galapagar es: {media_pps_galapagar:.2f} EUR/m²")
print("El precio por metro cuadrado en Galapagar es mayor en comparacion en Valdemorillo.")
# Out:
# La media de precio por metro cuadrado en Valdemorillo es: 1317.95 EUR/m²
# La media de precio por metro cuadrado en Galapagar es: 1606.32 EUR/m²
# El precio por metro cuadrado en Galapagar es mayor en comparacion en Valdemorillo.

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
plt.figure(figsize=(8, 4))
plt.scatter(df['surface'], df['price'], color='violet', edgecolor='purple', s=100, alpha=0.6)
plt.title('Relación entre superficie y precio de las casas', fontsize=16, fontweight='bold')
plt.xlabel('Superficie (m²)', fontsize=14, fontweight='bold')
plt.ylabel('Precio (€)', fontsize=14, fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.7)

zoom_area = [0, 6000, 0, 9000000]
plt.axhline(y=zoom_area[2], color='gray', linestyle='--', alpha=0.7)
plt.axhline(y=zoom_area[3], color='gray', linestyle='--', alpha=0.7)
plt.axvline(x=zoom_area[0], color='gray', linestyle='--', alpha=0.7)
plt.axvline(x=zoom_area[1], color='gray', linestyle='--', alpha=0.7)

plt.figure(figsize=(8, 4))
plt.scatter(df['surface'], df['price'], color='violet', edgecolor='purple', s=100, alpha=0.6)
plt.xlim(zoom_area[0], zoom_area[1])
plt.ylim(zoom_area[2], zoom_area[3])
plt.title('Zoom: Relación entre superficie y precio de las casas', fontsize=16, fontweight='bold')
plt.xlabel('Superficie (m²)', fontsize=14, fontweight='bold')
plt.ylabel('Precio (€)', fontsize=14, fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.7)

# %% [markdown]
# La mayoría de las casas tienen superficies entre 0 y 1000 metros cuadrados y sus precios suelen estar por debajo de los 3 millones de euros. Esto nos dice que la mayoría de las casas son relativamente pequeñas y de precio moderado.
# Hay algunas casas mucho más grandes, algunas llegando hasta los 250000 metros cuadrados, y con precios que pueden llegar a los 8 millones de euros. Estas casas son raras y están bastante dispersas en el gráfico, lo que significa que no es común encontrar propiedades de este tamaño y precio.
# En general, a mayor tamaño de la casa, mayor es el precio. Sin embargo, vemos mucha variabilidad en los precios para superficies similares.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
agencias = df['realEstate_name'].unique()
num_agencias = len(agencias)
print(f"El número de agencias de bienes raíces en el dataset es: {num_agencias}")
# Out:
# El número de agencias de bienes raíces en el dataset es: 1822

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
cuenta_casas = df['level5'].value_counts()
poblacion_mayor_cantidad = cuenta_casas.idxmax()
numero_casas = cuenta_casas.max()
print(f"La población con la mayor cantidad de casas es: {poblacion_mayor_cantidad} con {numero_casas} casas")
# Out:
# La población con la mayor cantidad de casas es:  Madrid Capital con 6643 casas

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
cinturon_sur_poblaciones = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
cinturon_sur = df[df['level5'].isin(cinturon_sur_poblaciones)]
print(cinturon_sur)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
media_precios = cinturon_sur.groupby('level5')['price'].mean()
media_precios.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Media de precios por población en el cinturón sur de Madrid')
plt.xlabel('Población')
plt.ylabel('Precio Medio')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Getafe lidera con los precios medios más altos, superando los 250,000 euros, seguido de cerca por Alcorcón con precios alrededor de los 220,000 euros. Leganés se encuentra en un rango medio, con precios medios de aproximadamente 200,000 euros. Fuenlabrada es la más asequible, con precios medios por debajo de los 180,000 euros. En resumen, Getafe y Alcorcón son las opciones más costosas, Leganés ofrece un punto intermedio, y Fuenlabrada es la opción más económica, ofreciendo diversas opciones para compradores con diferentes presupuestos en el cinturón sur de Madrid.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
variables = ['price', 'rooms', 'bathrooms', 'surface']

for var in variables:
    media = cinturon_sur[var].mean()
    varianza = cinturon_sur[var].var()
    print(f"Variable: {var}")
    print(f"  Media: {media:.2f}")
    print(f"  Varianza: {varianza:.2f}\n")
# Out:
# Variable: price
#   Media: 223094.48
#   Varianza: 14921367508.05
#
# Variable: rooms
#   Media: 3.02
#   Varianza: 0.72
#
# Variable: bathrooms
#   Media: 1.63
#   Varianza: 0.57
#
# Variable: surface
#   Media: 111.75
#   Varianza: 4263.05

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
casas_mas_caras = cinturon_sur.loc[cinturon_sur.groupby('level5')['price'].idxmax()]
print("La casa más cara de cada población:")
for index, row in casas_mas_caras.iterrows():
    print(f"Población: {row['level5']}, Dirección: {row['address']}, Precio: {row['price']}")

print("\nDataFrame con las casas más caras de cada población:")
print(casas_mas_caras[['level5', 'address', 'price']])
# Out:
# La casa más cara de cada población:
# Población: Alcorcón, Dirección: Alcorcón, Precio: 950000
# Población: Fuenlabrada, Dirección: Calle de Paulo Freire, 5, Fuenlabrada, Precio: 490000
# Población: Getafe, Dirección: Getafe, Precio: 1050000
# Población: Leganés, Dirección: Avenida Reina Sofía, Leganés, Precio: 650000
#
# DataFrame con las casas más caras de cada población:
#             level5                                address    price
# 5585      Alcorcón                               Alcorcón   950000
# 11561  Fuenlabrada  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881        Getafe                                 Getafe  1050000
# 10412      Leganés           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
cinturon_sur['precio_normalizado'] = cinturon_sur.groupby('level5')['price'].transform(
    lambda x: (x - x.mean()) / x.std()
)

plt.figure(figsize=(10, 6))

for poblacion in cinturon_sur_poblaciones:
    subset = cinturon_sur[cinturon_sur['level5'] == poblacion]
    plt.hist(subset['precio_normalizado'], bins=10, alpha=0.4, label=poblacion)

plt.title('Histogramas Normalizados de Precios por Población')
plt.xlabel('Precio Normalizado')
plt.ylabel('Frecuencia')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_1194/3851927062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cinturon_sur['precio_normalizado'] = cinturon_sur.groupby('level5')['price'].transform(

# %% [markdown]
# La mayor parte de las viviendas se concentra en la parte baja de la escala de precios, especialmente entre los valores normalizados de -1 y 1. Fuenlabrada y Leganés tienen una distribución de precios más concentrada cerca del centro, mientras que Getafe y Alcorcón muestran una mayor dispersión con algunas viviendas alcanzando precios significativamente más altos. Esto indica que, aunque la mayoría de las viviendas en todas las poblaciones tienen precios moderados, en Getafe y Alcorcón es más común encontrar viviendas con precios más elevados.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
getafe_pps = cinturon_sur[cinturon_sur['level5'] == 'Getafe']['pps']
alcorcon_pps = cinturon_sur[cinturon_sur['level5'] == 'Alcorcón']['pps']

print("Estadísticas descriptivas del precio por metro cuadrado (pps) en Getafe:")
print(getafe_pps.describe())
print("\nEstadísticas descriptivas del precio por metro cuadrado (pps) en Alcorcón:")
print(alcorcon_pps.describe())

plt. figure(figsize=(10, 6))
plt.hist(getafe_pps, bins=25, alpha=0.5, label='Getafe', color='orange') 
plt.hist(alcorcon_pps, bins=25, alpha=0.5, label='Alcorcón', color='yellow')
plt.xlabel('Precio por m²')
plt.ylabel('Frecuencia')
plt.title( 'Comparacion de precio por m² entre Getafe y Alcorcón')
plt.legend()
plt.show()
# Out:
# Estadísticas descriptivas del precio por metro cuadrado (pps) en Getafe:
# count     241.000000
# mean     2066.314949
# std       741.872702
# min         0.000000
# 25%      1684.285714
# 50%      1973.333333
# 75%      2628.787879
# max      3827.160494
# Name: pps, dtype: float64
#
# Estadísticas descriptivas del precio por metro cuadrado (pps) en Alcorcón:
# count     173.000000
# mean     2239.302480
# std       539.951527
# min       604.761905
# 25%      1904.081633
# 50%      2207.792208
# 75%      2472.727273
# max      3698.159509
# Name: pps, dtype: float64

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

axs = axs.flatten() 

for i, poblacion in enumerate(cinturon_sur_poblaciones):
    subset = cinturon_sur[cinturon_sur['level5'] == poblacion]
    axs[i].scatter(subset['surface'], subset['pps'], alpha=0.5, label=poblacion)
    axs[i].set_title(f'Precio por m² en {poblacion}')
    axs[i].set_xlabel('Superficie (m²)')
    axs[i].set_ylabel('Precio por m²')
    axs[i].legend()
    axs[i].grid(True)

plt.tight_layout()
plt.show()

# %%
colors = {
    'Fuenlabrada': 'springgreen',
    'Leganés': 'deepskyblue',
    'Getafe': 'darkviolet',
    'Alcorcón': 'deeppink'
}

plt.figure(figsize=(14, 10))

for poblacion in cinturon_sur_poblaciones:
    subset = cinturon_sur[cinturon_sur['level5'] == poblacion]
    plt.scatter(subset['surface'], subset['pps'], color=colors[poblacion], alpha=0.5, label=poblacion)

plt.title('Precio por m² en el Cinturón Sur')
plt.xlabel('Superficie (m²)')
plt.ylabel('Precio por m²')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps, Marker

# Mapa centrado en (60 grados latitud et -2.2 grados longitud)
# Latitud, longitud
map = Map(basemap=basemaps.OpenStreetMap.Mapnik, center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20)

# %%
coord_dict = cinturon_sur[['longitude', 'latitude']].to_dict(orient='records')

for coord in coord_dict:
    coord['longitude'] = float(coord['longitude'].replace(',', '.'))
    coord['latitude'] = float(coord['latitude'].replace(',', '.'))
    
    
for coord in coord_dict:
    marker = Marker(location=(coord['latitude'], coord['longitude']))
    map.add_layer(marker)
    
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…
